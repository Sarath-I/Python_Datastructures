# %% [markdown]
# <a href="https://colab.research.google.com/github/sarath-i/Python_Datastructures/blob/main/Python_Datastructures.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **Data structures in python**

# %% [markdown]
# # **Topic :List**

# %% [markdown]
# **Q1. Create a list of 5 random numbers and print the list.**

# %%
import random
numbers = []
for i in range(5):
    num = random.randint(1, 500)
    numbers.append(num)
print("List:", numbers)
# Out:
# List: [410, 114, 367, 386, 334]

# %% [markdown]
# **Q2. Insert 3 new values to the list and print the updated list.**

# %%
numbers.append(152)
numbers.append(320)
numbers.append(40)
print("Updated list:", numbers)
# Out:
# Updated list: [410, 114, 367, 386, 334, 152, 320, 40]

# %% [markdown]
# **Q3. Try to use a for loop to print each element in the list.**

# %%
print("Elements in the list:")
for num in numbers:
    print(num)
# Out:
# Elements in the list:
# 410
# 114
# 367
# 386
# 334
# 152
# 320
# 40

# %% [markdown]
# # **Topic: Dictionary**

# %% [markdown]
# **Q1. Create a dictionary with keys 'name', 'age', and 'address' and values 'John', 25, and 'New York' respectively.**

# %%
person = {
    "name": "John",
    "age": 25,
    "address": "New York"
}
print("Dictionary:", person)
# Out:
# Dictionary: {'name': 'John', 'age': 25, 'address': 'New York'}

# %% [markdown]
# **Q2. Add a new key-value pair to the dictionary created in Q1 with key 'phone' and value '1234567890'.**

# %%
person.update({"phone":"1234567890"})
print("Dictionary:", person)
# Out:
# Dictionary: {'name': 'John', 'age': 25, 'address': 'New York', 'phone': '1234567890'}

# %% [markdown]
# # **Topic: Set**

# %% [markdown]
# **Q1.Create a set with values 1, 2, 3, 4, and 5.**

# %%
a = {1, 2, 3, 4, 5}
print("Set:", a)
# Out:
# Set: {1, 2, 3, 4, 5}

# %% [markdown]
# **Q2. Add the value 6 to the set created in Q1.**

# %%
a.add(6)
print("Set:", a)
# Out:
# Set: {1, 2, 3, 4, 5, 6}

# %% [markdown]
# **Q3. Remove the value 3 from the set created in Q1.**

# %%
a.remove(3)
print("Set:", a)
# Out:
# Set: {1, 2, 4, 5, 6}

# %% [markdown]
# # **Topic:Tuple**

# %% [markdown]
# **Q1. Create a tuple with values 1, 2, 3, and 4**

# %%
b = (1, 2, 3, 4)
print("Tuple:", b)
# Out:
# Tuple: (1, 2, 3, 4)

# %% [markdown]
# **Q2. Print the length of the tuple created in Q1.**

# %%
print("Length of the tuple:", len(b))
# Out:
# Length of the tuple: 4
